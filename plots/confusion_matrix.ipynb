# %%
! pip install seaborn matplotlib pandas AST
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached matplotlib-3.9.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [21 lines of output]
#       Traceback (most recent call last):
#         File "C:\Users\MR\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#           main()
#         File "C:\Users\MR\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
# ...

# %%
! pip install scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/60.8 kB 1.3 MB/s eta 0:00:01
#      -------------------- ------------------- 30.7/60.8 kB 1.3 MB/s eta 0:00:01
#      -------------------- ------------------- 30.7/60.8 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 293.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.9 MB 726.2 kB/s eta 0:00:15
#    ---------------------------------------- 0.1/10.9 MB 726.2 kB/s eta 0:00:15
#    ---------------------------------------- 0.1/10.9 MB 726.2 kB/s eta 0:00:15
# ...

# %%
! pip install ast-tools
# Out:
# ...
#    ---------------------------------------- 0.0/43.6 kB ? eta -:--:--
#    ---------------------------------------- 43.6/43.6 kB 2.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.0 MB 1.9 MB/s eta 0:00:02
#     --------------------------------------- 0.0/2.0 MB 1.9 MB/s eta 0:00:02
#    - -------------------------------------- 0.1/2.0 MB 544.7 kB/s eta 0:00:04
#    -- ------------------------------------- 0.1/2.0 MB 652.2 kB/s eta 0:00:03
#    -- ------------------------------------- 0.1/2.0 MB 652.2 kB/s eta 0:00:03
#    -- ------------------------------------- 0.1/2.0 MB 450.6 kB/s eta 0:00:05
#    -- ------------------------------------- 0.1/2.0 MB 450.6 kB/s eta 0:00:05
#    -- ------------------------------------- 0.1/2.0 MB 450.6 kB/s eta 0:00:05
#    ---- ----------------------------------- 0.2/2.0 MB 573.4 kB/s eta 0:00:04
# ...

# %%
! pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached matplotlib-3.9.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.2.1-cp312-cp312-win_amd64.whl.metadata (5.8 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.53.0-cp312-cp312-win_amd64.whl.metadata (165 kB)
# ...
#   Using cached kiwisolver-1.4.5-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# ...
#   Using cached pillow-10.3.0-cp312-cp312-win_amd64.whl.metadata (9.4 kB)
# ...
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ----- ---------------------------------- 41.0/294.9 kB 2.0 MB/s eta 0:00:01
# ...

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import ast

# %%
# Internal validation 

import matplotlib.pyplot as plt

# Set the font sizes
SMALL_SIZE = 30
MEDIUM_SIZE = 32
BIGGER_SIZE = 40

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize

# Rest of your code...

# Read the data once
df = pd.read_csv("CML_prob.csv")

# Create a list of models
models = ['a) Logistic Regression', 'b) SVM', 'c) KNN', 'd) Decision Tree', 'e) Random Forest', 'f) XGboost', 'g) Neural Network']

# Determine the number of rows and columns for subplots
num_rows = 4
num_cols = 3

# Create subplots with a gray background
fig, axes = plt.subplots(num_rows, num_cols, figsize=(10 * num_cols, 8 * num_rows))

# Flatten the 2D array of axes for easy iteration
axes = axes.flatten()

# Iterate over models and plot confusion matrix
for i, model in enumerate(models):
    y_true = ast.literal_eval(df.loc[i, 'y_true'])
    y_pred = ast.literal_eval(df.loc[i, 'y_predicted'])

    # Create confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Create a heatmap using seaborn
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Died', 'Survived'], yticklabels=['Died', 'Survived'],
                ax=axes[i], annot_kws={'fontsize': 15})  # Adjust the fontsize as needed
    
    axes[i].set_title(f'{model} ', fontsize=BIGGER_SIZE)
    axes[i].set_xlabel('Predicted', fontsize=SMALL_SIZE)
    axes[i].set_ylabel('Actual', fontsize=SMALL_SIZE)

# Remove empty subplots
for i in range(len(models) + 3, num_rows * num_cols + 1):
    fig.delaxes(axes[i - 1])
fig.delaxes(axes[8])
fig.delaxes(axes[7])
# Add a note under the subplots
#fig.text(0.5, 0.25, 'Internal Validation test', ha='center', fontsize=BIGGER_SIZE, va='center')
plt.subplots_adjust(hspace=0.7, wspace=0.7)
# Adjust layout
#plt.subplots_adjust(hspace=0.5)

#plt.show()
plt.savefig("CML_in_cm.pdf")

# %%
import matplotlib.pyplot as plt

# Set the font sizes
SMALL_SIZE = 30
MEDIUM_SIZE = 32
BIGGER_SIZE = 40

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize

# Rest of your code...

# Read the data once
df = pd.read_csv("CML_prob.csv")

# Create a list of models
models = ['a) Logistic Regression', 'b) SVM', 'c) KNN', 'd) Decision Tree', 'e) Random Forest', 'f) XGboost', 'g) Neural Network']

# Determine the number of rows and columns for subplots
num_rows = 4
num_cols = 3

# Create subplots with a gray background
fig, axes = plt.subplots(num_rows, num_cols, figsize=(10 * num_cols, 8 * num_rows))

# Flatten the 2D array of axes for easy iteration
axes = axes.flatten()

# Iterate over models and plot confusion matrix
for i, model in enumerate(models):
    y_true = ast.literal_eval(df.loc[i, 'y_true_ex'])
    y_pred = ast.literal_eval(df.loc[i, 'y_predicted_ex'])

    # Create confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Create a heatmap using seaborn
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Died', 'Survived'], yticklabels=['Died', 'Survived'],
                ax=axes[i], annot_kws={'fontsize': 15})  # Adjust the fontsize as needed
    
    axes[i].set_title(f'{model} ', fontsize=BIGGER_SIZE)
    axes[i].set_xlabel('Predicted', fontsize=MEDIUM_SIZE)
    axes[i].set_ylabel('Actual', fontsize=MEDIUM_SIZE)

# Remove empty subplots
for i in range(len(models) + 3, num_rows * num_cols + 1):
    fig.delaxes(axes[i - 1])
fig.delaxes(axes[8])
fig.delaxes(axes[7])
# Add a note under the subplots
#fig.text(0.5, 0.25, 'Internal Validation test', ha='center', fontsize=BIGGER_SIZE, va='center')
plt.subplots_adjust(hspace=0.7, wspace=0.7)

# Adjust layout
#plt.subplots_adjust(hspace=0.5)

plt.show()
#plt.savefig("CML_ex_cm.pdf")

# %%
multi = pd.read_csv('zero_shot_by_hand - Sheet1.csv')
multi = multi.replace('survive', 1)
multi = multi.replace('die', 0)
y_true = multi[['Inhospital Mortalit(TRUE)']]
mixtral = multi[['Mixtral-8x7B-Instruct-v0.1 ']]
llama370= multi[['Llama-3-70B']]
mistral7b=multi[['Mistral-7B-Instruct']]
llama38=multi[['-Llama-3-8B']]
gpt_4o = multi[['gpt-4o-2024-05-13_outcome']]
gpt_35_turbo = multi[['gpt-3.5-turbo-0125_outcome']]
gpt_4_turbo = multi[['gpt-4-turbo-2024-04-09_outcome']]
gpt_4 = multi[['gpt-4-0613_outcome']]
# Out:
# C:\Users\MR\AppData\Local\Temp\ipykernel_5716\4292102868.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   multi = multi.replace('die', 0)

# %%
# Determine the number of rows and columns for subplots
num_rows = 4
num_cols = 3

# Create subplots with a gray background
fig, axes = plt.subplots(num_rows, num_cols, figsize=(10 * num_cols, 8 * num_rows))
# Set the font sizes
SMALL_SIZE = 30
MEDIUM_SIZE = 32
BIGGER_SIZE = 40

# Flatten the 2D array of axes for easy iteration
axes = axes.flatten()
# Create confusion matrix for zero-shot classification
cm_zero_shot = confusion_matrix(y_true, mixtral)
plt.subplot(num_rows, num_cols, 1 )
sns.heatmap(cm_zero_shot, annot=True, fmt='d', cmap='Reds', xticklabels=['Died', 'Survived'], yticklabels=['Died', 'Survived'])
plt.title('a) Mixtral-8x7B-Instruct-v0.1',fontsize=BIGGER_SIZE)
plt.xlabel('Predicted',fontsize=MEDIUM_SIZE)
plt.ylabel('Actual',fontsize=MEDIUM_SIZE)

cm_zero_shot = confusion_matrix(y_true, llama370)
plt.subplot(num_rows, num_cols, 2 )
sns.heatmap(cm_zero_shot, annot=True, fmt='d', cmap='Reds', xticklabels=['Died', 'Survived'], yticklabels=['Died', 'Survived'])
plt.title('b) Llama-3-70B',fontsize=BIGGER_SIZE)
plt.xlabel('Predicted',fontsize=MEDIUM_SIZE)
plt.ylabel('Actual',fontsize=MEDIUM_SIZE)

cm_zero_shot = confusion_matrix(y_true, mistral7b)
plt.subplot(num_rows, num_cols, 3 )
sns.heatmap(cm_zero_shot, annot=True, fmt='d', cmap='Reds', xticklabels=['Died', 'Survived'], yticklabels=['Died', 'Survived'])
plt.title('c) Mistral-7B-Instruct',fontsize=BIGGER_SIZE)
plt.xlabel('Predicted',fontsize=MEDIUM_SIZE)
plt.ylabel('Actual',fontsize=MEDIUM_SIZE)

cm_zero_shot = confusion_matrix(y_true, llama38)
plt.subplot(num_rows, num_cols, 4 )
sns.heatmap(cm_zero_shot, annot=True, fmt='d', cmap='Reds', xticklabels=['Died', 'Survived'], yticklabels=['Died', 'Survived'])
plt.title('d) Llama-3-8B',fontsize=BIGGER_SIZE)
plt.xlabel('Predicted',fontsize=MEDIUM_SIZE)
plt.ylabel('Actual',fontsize=MEDIUM_SIZE)

cm_zero_shot = confusion_matrix(y_true, gpt_4o)
plt.subplot(num_rows, num_cols, 5 )
sns.heatmap(cm_zero_shot, annot=True, fmt='d', cmap='Reds', xticklabels=['Died', 'Survived'], yticklabels=['Died', 'Survived'])
plt.title('e) gpt-4o',fontsize=BIGGER_SIZE)
plt.xlabel('Predicted',fontsize=MEDIUM_SIZE)
plt.ylabel('Actual',fontsize=MEDIUM_SIZE)

cm_zero_shot = confusion_matrix(y_true, gpt_35_turbo)
plt.subplot(num_rows, num_cols, 6 )
sns.heatmap(cm_zero_shot, annot=True, fmt='d', cmap='Reds', xticklabels=['Died', 'Survived'], yticklabels=['Died', 'Survived'])
plt.title('f) gpt-3.5-turbo',fontsize=BIGGER_SIZE)
plt.xlabel('Predicted',fontsize=MEDIUM_SIZE)
plt.ylabel('Actual',fontsize=MEDIUM_SIZE)

cm_zero_shot = confusion_matrix(y_true, gpt_4_turbo)
plt.subplot(num_rows, num_cols, 7 )
sns.heatmap(cm_zero_shot, annot=True, fmt='d', cmap='Reds', xticklabels=['Died', 'Survived'], yticklabels=['Died', 'Survived'])
plt.title('g) gpt-4-turbo',fontsize=BIGGER_SIZE)
plt.xlabel('Predicted',fontsize=MEDIUM_SIZE)
plt.ylabel('Actual',fontsize=MEDIUM_SIZE)

cm_zero_shot = confusion_matrix(y_true, gpt_4)
plt.subplot(num_rows, num_cols, 8 )
sns.heatmap(cm_zero_shot, annot=True, fmt='d', cmap='Reds', xticklabels=['Died', 'Survived'], yticklabels=['Died', 'Survived'])
plt.title('h) gpt-4',fontsize=BIGGER_SIZE)
plt.xlabel('Predicted',fontsize=MEDIUM_SIZE)
plt.ylabel('Actual',fontsize=MEDIUM_SIZE)
# Add a note under the subplots
#fig.text(0.5, 0.02, 'Zero shot classification', ha='center', fontsize=18, va='center')
for i in range(9, num_rows * num_cols + 1):
    fig.delaxes(axes[i - 1])
#fig.delaxes(axes[8])
# Adjust the spacing between subplots
plt.subplots_adjust(hspace=0.7, wspace=0.7)
plt.savefig("zero_shot_tuned_cm.pdf")

# %%
num_rows = 1
num_cols = 2

# Create subplots with a gray background
fig, axes = plt.subplots(num_rows, num_cols, figsize=(10 * num_cols, 8 * num_rows))

# Add internal fine-tuning plot
# Read the data for internal fine-tuning
df_internal_fine_tuning = pd.read_csv("4epochs_mistral_internaltest_predictions.csv")
y_true_internal_fine_tuning = df_internal_fine_tuning["y_true"]
y_pred_internal_fine_tuning = df_internal_fine_tuning["y_pred"]

# Create confusion matrix for internal fine-tuning
cm_internal_fine_tuning = confusion_matrix(y_true_internal_fine_tuning, y_pred_internal_fine_tuning)

# Create a heatmap using seaborn for internal fine-tuning
plt.subplot(num_rows, num_cols, 1)
sns.heatmap(cm_internal_fine_tuning, annot=True, fmt='d', cmap='Greens', xticklabels=['Died', 'Survived'], yticklabels=['Died', 'Survived'],
            annot_kws={"fontsize": 15})  # Adjust fontsize as needed
plt.title('a) Internal validation test',fontsize=BIGGER_SIZE)
plt.xlabel('Predicted',fontsize=MEDIUM_SIZE)
plt.ylabel('Actual',fontsize=MEDIUM_SIZE)

# Add internal fine-tuning plot
# Read the data for internal fine-tuning
df_internal_fine_tuning = pd.read_csv("4epochs_mistral_external_test_predictions.csv")
y_true_internal_fine_tuning = df_internal_fine_tuning["y_true"]
y_pred_internal_fine_tuning = df_internal_fine_tuning["y_pred"]

# Create confusion matrix for internal fine-tuning
cm_internal_fine_tuning = confusion_matrix(y_true_internal_fine_tuning, y_pred_internal_fine_tuning)

# Create a heatmap using seaborn for internal fine-tuning
plt.subplot(num_rows, num_cols, 2)
sns.heatmap(cm_internal_fine_tuning, annot=True, fmt='d', cmap='Greens', xticklabels=['Died', 'Survived'], yticklabels=['Died', 'Survived'],
            annot_kws={"fontsize": 15})  # Adjust fontsize as needed
# Add a note under the subplots
#fig.text(0.5, -0.1, 'Fine tuned Mistral-7B-Instruct', ha='center', fontsize=18, va='center')
plt.subplots_adjust(hspace=0.7, wspace=0.7)
plt.title('b) External validation',fontsize=BIGGER_SIZE)
plt.xlabel('Predicted',fontsize=MEDIUM_SIZE)
plt.ylabel('Actual',fontsize=MEDIUM_SIZE)
plt.savefig("fine_tuned_cm.pdf")

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\MR\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\pyplot.py'>
